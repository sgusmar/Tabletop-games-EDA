# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
bgg_data = pd.DataFrame()
json_test = pd.read_json('data/bgg_batch_test.json')
json_test.head()
# Out:
#    row_id       type                  boardgame  \
# 0  224517  boardgame          Brass: Birmingham
# 1  342942  boardgame                   Ark Nova
# 2  161936  boardgame  Pandemic Legacy: Season 1
# 3  174430  boardgame                 Gloomhaven
# 4  397598  boardgame  Dune: Imperium – Uprising
#
#                                          description  min_players  \
# 0  Brass: Birmingham is an economic strategy game...            2
# 1  In Ark Nova, you will plan and design a modern...            1
# 2  Pandemic Legacy is a co-operative campaign gam...            2
# 3  Gloomhaven  is a game of Euro-inspired tactica...            1
# 4  In Dune: Imperium Uprising, you want to contin...            1
#
#    max_players                               suggested_numplayers  \
# 0            4  {'Best': '4', 'Recommended': '2', 'Not Recomme...
# 1            4  {'Best': '2', 'Recommended': '3', 'Not Recomme...
# 2            4  {'Best': '4', 'Recommended': '2', 'Not Recomme...
# ...

# %%
json_test.info()
json_test.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id                500 non-null    int64
#  1   type                  500 non-null    str
#  2   boardgame             500 non-null    str
#  3   description           500 non-null    str
#  4   min_players           500 non-null    int64
#  5   max_players           500 non-null    int64
#  6   suggested_numplayers  500 non-null    object
#  7   min_playtime          500 non-null    int64
#  8   max_playtime          500 non-null    int64
#  9   playingtime           500 non-null    int64
#  10  minimum_age           500 non-null    int64
#  11  release_year          500 non-null    int64
#  12  average_rating        500 non-null    float64
#  13  num_of_ratings        500 non-null    int64
#  14  weight                500 non-null    float64
# ...

# %%
json_test['release_year'] = pd.to_numeric(json_test['release_year'], errors='coerce')
json_test['min_players'] = pd.to_numeric(json_test['min_players'], errors='coerce')
json_test['max_players'] = pd.to_numeric(json_test['max_players'], errors='coerce')
json_test['min_playtime'] = pd.to_numeric(json_test['min_playtime'], errors='coerce')
json_test['max_playtime'] = pd.to_numeric(json_test['max_playtime'], errors='coerce')
json_test['playingtime'] = pd.to_numeric(json_test['playingtime'], errors='coerce')
json_test['minimum_age'] = pd.to_numeric(json_test['minimum_age'], errors='coerce')
json_test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id                500 non-null    int64
#  1   type                  500 non-null    str
#  2   boardgame             500 non-null    str
#  3   description           500 non-null    str
#  4   min_players           500 non-null    int64
#  5   max_players           500 non-null    int64
#  6   suggested_numplayers  500 non-null    object
#  7   min_playtime          500 non-null    int64
#  8   max_playtime          500 non-null    int64
#  9   playingtime           500 non-null    int64
#  10  minimum_age           500 non-null    int64
#  11  release_year          500 non-null    int64
#  12  average_rating        500 non-null    float64
#  13  num_of_ratings        500 non-null    int64
#  14  weight                500 non-null    float64
# ...

# %%
json_test[['suggested_numplayers','ranks', "categories", "mechanisms", "family", "designers", "artists","publishers"]]
# Out:
#                                   suggested_numplayers  \
# 0    {'Best': '4', 'Recommended': '2', 'Not Recomme...
# 1    {'Best': '2', 'Recommended': '3', 'Not Recomme...
# 2    {'Best': '4', 'Recommended': '2', 'Not Recomme...
# 3    {'Best': '3', 'Recommended': '2', 'Not Recomme...
# 4    {'Best': '4', 'Recommended': '3', 'Not Recomme...
# ..                                                 ...
# 495  {'Best': '2', 'Recommended': '3', 'Not Recomme...
# 496  {'Best': '3', 'Recommended': '2', 'Not Recomme...
# 497  {'Best': '2', 'Recommended': '2+', 'Not Recomm...
# 498  {'Best': '6', 'Recommended': '4', 'Not Recomme...
# 499  {'Best': '3', 'Recommended': '1', 'Not Recomme...
#
#                                                  ranks  \
# 0             {'boardgame': '1', 'strategygames': '1'}
# 1             {'boardgame': '2', 'strategygames': '2'}
# 2    {'boardgame': '3', 'thematic': '1', 'strategyg...
# 3    {'boardgame': '4', 'thematic': '2', 'strategyg...
# ...

# %% [markdown]
# Generamos tablas accesorias para eliminar las listas

# %%
game_designers = json_test[['row_id','designers']]
game_designers = game_designers.explode('designers')

game_artists = json_test[['row_id','artists']]
game_artists = game_artists.explode('artists')
game_artists.head()
# Out:
#        suggested_numplayers
# row_id
# 224517                  NaN
# 342942                  NaN
# 161936                  NaN
# 174430                  NaN
# 397598                  NaN
# ...                     ...
# 368305                  NaN
# 286751                  NaN
# 101721                  NaN
# 454103                  NaN
# 367041                  NaN
#
# [500 rows x 1 columns]

# %% [markdown]
# En el caso de

# %%
# Expandir el diccionario de suggested_numplayers en columnas separadas
suggested_players_expanded = json_test['suggested_numplayers'].apply(pd.Series)
print(suggested_players_expanded)
# Combinar con row_id
suggested_numplayers_table = pd.concat([json_test['row_id'], suggested_players_expanded], axis=1)

# suggested_numplayers_table.head(20)
# Out:
#     Best Recommended Not Recommended
# 0      4           2               1
# 1      2           3              4+
# 2      4           2              4+
# 3      3           2              4+
# 4      4           3               5
# ..   ...         ...             ...
# 495    2           3               4
# 496    3           2              6+
# 497    2          2+               1
# 498    6           4               1
# 499    3           1              4+
#
# [500 rows x 3 columns]
